# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# All data

# %%
df = pd.read_csv('losses.csv', index_col=False)[1:]

plt.plot(df.loss_train, label='train')
plt.plot(df.loss_test, label='test')

# %% [markdown]
# Last n

# %%
last_n = 127
df = pd.read_csv('losses.csv', index_col=False)

plt.figure(figsize=(5,5))
plt.plot(df.loss_train[-last_n:])
plt.plot(df.loss_test[-last_n:])
